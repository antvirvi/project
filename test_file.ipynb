# %%
file_in=open("medium_dynamic.init","r")
try:
    file_out=open("medium_dynamic.work","rw")
except:
    file_out=open("medium_dynamic.work","rw")
    
try:
    file_out2=open("medium_dynamic_test.work","w")
except:
    file_out2=open("medium_dynamic_test.work","w")

# %%
for line in file_in:
    temp="D "
    temp=temp+line
    file_out.write(temp)
    
file_in.close()
file_out.close()

# %%
for line in file_out:
    first_word=line.split()[0]
    print(first_word)
    if(first_word!="Q"):
        file_out2.write(line)
    
file_in.close()
file_out.close()
# Out:
# D
# Q
# A
# A
# A
# A
# Q
# A
# A
# A
# A
# A
# Q
# A
# A
# Q
# A
# Q
# A
# A
# A
# Q
# A
# A
# D
# A
# A
# A
# A
# Q
# A
# A
# A
# A
# A
# Q
# A
# A
# Q
# D
# D
# A
# A
# Q
# Q
# Q
# Q
# Q
# A
# D
# D
# A
# A
# Q
# A
# A
# A
# A
# A
# A
# D
# A
# A
# A
# A
# A
# A
# D
# A
# A
# A
# A
# A
# A
# A
# A
# D
# A
# A
# D
# A
# A
# A
# Q
# A
# A
# D
# D
# A
# A
# A
# A
# A
# A
# A
# A
# D
# A
# A
# A
# Q
# D
# D
# A
# Q
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# Q
# Q
# A
# A
# D
# A
# A
# A
# Q
# D
# D
# A
# A
# A
# A
# Q
# Q
# A
# A
# D
# Q
# A
# A
# A
# D
# A
# A
# A
# A
# Q
# A
# A
# A
# A
# A
# D
# Q
# A
# A
# A
# A
# D
# D
# A
# A
# A
# A
# A
# A
# Q
# A
# D
# A
# A
# D
# A
# D
# A
# A
# A
# A
# A
# A
# Q
# Q
# A
# A
# Q
# A
# A
# A
# A
# D
# D
# A
# A
# A
# A
# A
# A
# A
# A
# A
# Q
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# D
# A
# Q
# D
# A
# D
# A
# A
# A
# A
# A
# Q
# Q
# A
# A
# A
# A
# Q
# A
# D
# A
# A
# A
# A
# D
# A
# A
# D
# D
# A
# A
# A
# Q
# A
# ...
