# %%
file_in=open("small.init","r")
try:
    file_out=open("small_test.work","w")
except:
    file_out=open("small_test.work","w")

# %%
for line in file_in:
    temp="D "
    temp=temp+line
    file_out.write(temp)
    
file_in.close()
file_out.close()
# Out:
# hubble
#
# line is  puthuppadi
#
# line is  ngc 6946
#
# line is  penrose diagram
#
# line is  parameter
#
# line is  sculptor
#
# line is  electron microscopy
#
# line is  conditional
#
# line is  mulakkuzha
#
# line is  varying
#
# line is  wegner
#
# line is  pravdo
#
# line is  magnano
#
# line is  halo 9
#
# line is  wavelengths
#
# line is  benson
#
# line is  b k
#
# line is  corbet
#
# line is  correlation function
#
# line is  bower
#
# line is  abell clusters
#
# line is  monaco
#
# line is  heggie
#
# line is  monoceros ring
#
# line is  batse
#
# line is  operator
#
# line is  astron lett
#
# line is  reproduction
#
# line is  quasars
#
# line is  pollack
#
# line is  johnson
#
# line is  australian
#
# line is  fig 8
#
# line is  d e
#
# line is  savvas
#
# line is  1 million
#
# line is  indices
#
# line is  spitzer
#
# line is  slane
#
# line is  means
#
# line is  template
#
# line is  eventually
#
# line is  notice
#
# line is  components
#
# line is  transform
#
# ...
